# %%
try:
    sys.path.remove('/opt/ros/kinetic/lib/python2.7/dist-packages')
except:
    pass

import cv2
import dlib
import numpy as np
import imutils
from imutils import face_utils
import matplotlib.pyplot as plt

# %%
#initialize facial detector
# detector = dlib.get_frontal_face_detector()
# predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')

# %%
# gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
# gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
# img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# img1 = imutils.resize(gray1,width = 600, height = 600)
# img2 = imutils.resize(gray2,width = 600, height = 600)

# %%
def features(img):
    #initialize facial detector
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray,(200,200))
    img = cv2.resize(img,(200,200))
    
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')
    rects = detector(gray,1)
    
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    for (i,rect) in enumerate(rects):
        
        shape = predictor(gray,rect)
        shape = face_utils.shape_to_np(shape)


        (x,y,w,h) = face_utils.rect_to_bb(rect)
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)


        for (x,y) in shape:
            cv2.circle(img,(x,y),2,(0,0,255),-1)
    return img, shape

# %%
img = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/2faces.png')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# gray = cv2.resize(gray,(200,200))
# img = cv2.resize(img,(200,200))

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('/home/abhinav/CMSC-733/Abhi1625_p2/shape_predictor.dat')
rects = detector(gray,2)


img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
for (i,rect) in enumerate(rects):

    shape = predictor(gray,rect)
    shape = face_utils.shape_to_np(shape)


    (x,y,w,h) = face_utils.rect_to_bb(rect)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)


    for (x,y) in shape:
        cv2.circle(img,(x,y),2,(0,0,255),-1)
        
plt.imshow(img)

# %%
# new_img1 = np.zeros(200)
# new_img2 = np.zeros(200)

new_img1 = img[rects[0].top()-40:rects[0].bottom()+40,rects[0].left()-40:rects[0].right()+40,:]
plt.imshow(new_img1)

if len(rects) >1:
    img_source = img[rects[0].top()-40:rects[0].bottom()+40,rects[0].left()-40:rects[0].right()+40,:]
    img_target = img[rects[1].top()-40:rects[1].bottom()+40,rects[1].left()-40:rects[1].right()+40,:]
    
plt.imshow(img_source)
# plt.imshow(img_target)

# %%
rects[0].bottom()
# Out:
# 492L

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('./shape_predictor.dat')
# /home/pratique/Downloads/cmsc733-Pictorial Information/project_2_face_swap/YourDirectoryID_p2
#Setup input video
cap1 = cv2.VideoCapture('./john.mp4')
#cap2 = cv2.VideoCapture('.')
i=0
img_tar = cv2.imread('./imgs/anton.jpg')

while(True):
    ret1,img_src = cap1.read()
    if((not ret1)):
        break

    # ret,img_src= cap.read()
    # plt.imsrhow(img_src)
    # plt.show()
    print(img_src.dtype)
    # img_src = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/chahat_c.jpeg')
    rects = detector(img_src)
    img_source = img_src.copy()
    if len(rects)>1:
        img_target = img_source[rects[1].top()-40:rects[1].bottom()+40,rects[1].left()-40:rects[1].right()+40,:]
    else:
        img_target = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/imgs/joker.jpg')
    # img_source = cv2.resize(img_src,(200,200))
    # img_source = cv2.cvtColor(img_source,cv2.COLOR_BGR2RGB)
    # img_target = cv2.resize(img_tar,(200,200))
    # img_target = cv2.cvtColor(img_target,cv2.COLOR_BGR2RGB)
    img_source = img_source[rects[0].top()-40:rects[0].bottom()+40,rects[0].left()-40:rects[0].right()+40,:]
    img1 = img_source.copy()
    img2 = img_target.copy()


    # print(ret)
    # plt.imshow(img_src)
    # plt.show()
    # print(img_src.dtype)
    # img_src = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/chahat_c.jpeg')
    # img_tar = cv2.imread('./Data/stephen.mp4')
    # shape1= np.shape(img_src)[:2]
    # shape2= np.shape(img_tar)[:2]
    # # print('shape1 = '+str(shape1)+'shape2 = '+str(shape2))
    # a = np.minimum(shape1,shape2)
    # # print(a)
    # a = np.minimum(a[0],a[1])
    # print('final dim  = '+str(a))
    a=200
    # img_source = cv2.resize(img_src,(a,a))
    # img_source = cv2.cvtColor(img_source,cv2.COLOR_BGR2RGB)
    # img_target = cv2.resize(img_tar,(a,a))
    # img_target = cv2.cvtColor(img_target,cv2.COLOR_BGR2RGB)
    # img1 = img_src.copy()
    # img2 = img_tar.copy()
    cv2.imshow('test1',img1)
    cv2.imshow('test2',img2)
    img1,points1, flag1 = features(img1,detector,predictor,a)
    img2,points2, flag2 = features(img2,detector, predictor,a)
    if(flag1==False or flag2==False):
        print('skipping frame, 68 features not found')
        continue

    output1 = swap(img_source.copy(),img_target.copy(),points1,points2)
    output2 = swap(img_target.copy(),img_source.copy(),points2,points1)
    cv2.imwrite('./result1/'+str(i)+'.jpg',output1)
    cv2.imwrite('./result2/'+str(i)+'.jpg',output2)
    print('saved '+str(i)+' frames')
    i = i+1
    k = cv2.waitKey(0)
    if k & 0xff==ord('q'):
        cv2.destroyAllWindows()
        break
# Out:
# uint8
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-172-a6c74ac45237> in <module>()
#      53     # img1 = img_src.copy()
#      54     # img2 = img_tar.copy()
# ---> 55     cv2.imshow('test1',img1)
#      56     cv2.imshow('test2',img2)
#      57     img1,points1, flag1 = features(img1,detector,predictor,a)
#
# error: /tmp/binarydeb/ros-kinetic-opencv3-3.3.1/modules/highgui/src/window.cpp:331: error: (-215) size.width>0 && size.height>0 in function imshow

# %%
plt.imshow(img2)

# %%
img_src = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/chahat_c.jpeg')
img_tar = cv2.imread('/home/abhinav/CMSC-733/Abhi1625_p2/nitin.jpg')
img_source = cv2.resize(img_src,(200,200))
img_source = cv2.cvtColor(img_source,cv2.COLOR_BGR2RGB)
img_target = cv2.resize(img_tar,(200,200))    
img_target = cv2.cvtColor(img_target,cv2.COLOR_BGR2RGB)
img1 = img_src.copy()
img2 = img_tar.copy()

img1,shape1 = features(img1)
img2,shape2 = features(img2)

# %%
# def get_face_params(img,feature_points, allowance=10):
# #   input---
# #   img: input image
# #   feature_points: numpy array of feature points from dlib predictor 
# #   allowance: extra region to house face in a rectangle

# #   output---
# #   cropped face
# #   shifted feature points w.r.t cropped face
# #   height and width of cropped image

#     im_w, im_h = img.shape[:2]
#     # finding leftmost point in the image
#     print(feature_points)
#     left, top = np.min(feature_points.astype(np.uint8), 0)
#     if left<top:
#         top = left
#     else:
#         left = top
#     # finding bottom right point in the image
#     right, bottom = np.max(feature_points.astype(np.uint8), 0)
#     if right>bottom:
#         bottom = right
#     else:
#         right = bottom
    
#     x, y = max(0, left-allowance), max(0, top-allowance)
#     w, h = min(right+allowance, im_h)-x, min(bottom+allowance, im_w)-y
#     new_points = feature_points - np.asarray([[x, y]])
#     rect = (x, y, w, h)
#     cropped_img = img[y:y+h, x:x+w]
#     return new_points, rect, cropped_img

# # shape1, src_shape, img_source = get_face_params(img_source.copy(), shape1)
# # shape2, dst_shape, img_target = get_face_params(img_target.copy(), shape2)

# %%
shape1
# Out:
# array([[ 67,  96],
#        [ 67, 104],
#        [ 67, 113],
#        [ 68, 122],
#        [ 71, 130],
#        [ 76, 138],
#        [ 82, 144],
#        [ 91, 148],
#        [101, 149],
#        [110, 147],
#        [119, 143],
#        [125, 137],
#        [130, 129],
#        [133, 121],
#        [134, 112],
#        [134, 104],
#        [134,  96],
#        [ 73,  87],
#        [ 77,  81],
#        [ 83,  78],
#        [ 90,  78],
#        [ 96,  80],
#        [106,  80],
#        [112,  78],
#        [119,  79],
#        [125,  82],
#        [128,  88],
#        [102,  88],
#        [102,  93],
#        [102,  98],
#        [103, 104],
#        [ 95, 108],
#        [ 98, 110],
#        [102, 111],
#        [106, 110],
#        [109, 108],
#        [ 82,  91],
#        [ 85,  88],
#        [ 89,  88],
#        [ 93,  91],
#        [ 89,  92],
#        [ 85,  92],
#        [109,  91],
#        [113,  89],
#        [117,  89],
#        [121,  92],
#        [117,  92],
#        [113,  92],
#        [ 86, 119],
#        [ 92, 117],
#        [ 97, 116],
#        [102, 116],
#        [106, 116],
#        [110, 117],
#        [115, 119],
#        [110, 123],
#        [105, 124],
#        [101, 125],
#        [ 97, 124],
#        [ 91, 123],
#        [ 88, 119],
#        [ 97, 119],
#        [101, 119],
#        [106, 119],
#        [113, 119],
#        [105, 120],
#        [101, 121],
#        [ 97, 120]])

# %%
plt.imshow(img_source)

# %%
plt.imshow(img_target)

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(img1)

# %%
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(img2)

# %%
#Thin Plate Splines
import math
import sys
def U(r):
    return (r**2)*(math.log(r**2))
def TPS_generate(source,target):
    P = np.append(source,np.ones([source.shape[0],1]),axis=1)
    P_Trans = P.T
    Z = np.zeros([3,3])
    K = np.zeros([source.shape[0],source.shape[0]])
    for p in range(source.shape[0]):
        K[p] = [U(np.linalg.norm((-source[p]+source[i]),ord =2)+sys.float_info.epsilon) for i in range(source.shape[0])]

    M = np.vstack([np.hstack([K,P]),np.hstack([P_Trans,Z])])
    lam = 500
    I = np.identity(M.shape[0])
    L = M+lam*I
    L_inv = np.linalg.inv(L)
    V = np.concatenate([np.array(target),np.zeros([3,])])
    V.resize(V.shape[0],1)
    weights = np.matmul(L_inv,V)
    return weights,K

# %%
# plt.imshow(K)

# %%
weights_x,K = TPS_generate(shape1,shape2[:,0])
weights_y,K = TPS_generate(shape1,shape2[:,1])
# def ind2sub(array_shape, ind):
#     ind[ind < 0] = -1
#     ind[ind >= array_shape[0]*array_shape[1]] = -1
#     rows = (ind.astype('int') / array_shape[1])
#     cols = ind % array_shape[1]
#     return (rows, cols)
plt.imshow(K)

# %%
def mask_from_points(size, points,erode_flag=1):
    radius = 10  # kernel size
    kernel = np.ones((radius, radius), np.uint8)

    mask = np.zeros(size, np.uint8)
    cv2.fillConvexPoly(mask, cv2.convexHull(points), 255)
    if erode_flag:
        mask = cv2.erode(mask, kernel,iterations=1)

    return mask

# %%
w, h = img_target.shape[:2]
# ## Mask for blending
mask = mask_from_points((w, h), shape2)

# %%
plt.imshow(mask)
mask.shape
# Out:
# (200, 200)

# %%
# ## Copy-and-paste
# def apply_mask(img, mask):
#     """ Apply mask to supplied image
#     :param img: max 3 channel image
#     :param mask: [0-255] values in mask
#     :returns: new image with mask applied
#     """
#     masked_img=cv2.bitwise_and(img,img,mask=mask)

#     return masked_img

# mask_src = np.mean(img_target.copy(), axis=2) > 0
# mask = np.asarray(mask*mask_src, dtype=np.uint8)
# print(mask.shape)
# # plt.imshow(warped_src_face)
# ## Correct color
# # if not args.warp_2d and args.correct_color:
# warped_src_face = apply_mask(img_target.copy(), mask.copy())
# plt.imshow(warped_src_face)

# %%
#VERIFY THIS
def fxy(pt1,pts2,weights):
    K = np.zeros([pts2.shape[0],1])
    for i in range(pts2.shape[0]):
        K[i] = U(np.linalg.norm((pts2[i]-pt1),ord =2)+sys.float_info.epsilon) 
    f = weights_x[-1] + weights[-3]*pt1[0] +weights[-2]*pt1[1]+np.matmul(K.T,weights[0:-3])
    return f

# %%
def warp_tps(img_source,img_target,shape1,shape2,weights_x,weights_y):
    xy1_min = np.float32([min(shape1[:,0]),min(shape1[:,1])])
    xy1_max = np.float32([max(shape1[:,0]),max(shape1[:,1])])

    x = np.arange(xy1_min[0],xy1_max[0]).astype(int)
    y = np.arange(xy1_min[1],xy1_max[1]).astype(int)

    X,Y = np.mgrid[x[0]:x[-1]+1,y[0]:y[-1]+1]

    # X,Y = np.mgrid[0:src_shape[2],0:src_shape[3]]
    pts_src = np.vstack((X.ravel(),Y.ravel()))
    xy = pts_src.T
    u = np.zeros_like(xy[:,0])
    v = np.zeros_like(xy[:,0])
    # print(u.shape)
    # print(v.shape)
    for i in range(xy.shape[0]):
        u[i] = fxy(xy[i,:],shape1,weights_x)
    # u[u<xy2_min[0]]=xy2_min[0]
    # u[u>xy2_max[0]]=xy2_max[0]
    for j in range(xy.shape[0]):
        v[j] = fxy(xy[j,:],shape1,weights_y)
    # v[v<xy2_min[1]]=xy2_min[1]
    # v[v>xy2_max[1]]=xy2_max[1]
#     print(u.shape)
#     print(img_source.shape)
    warped_img = img_source.copy()
    mask_warped_img = np.zeros_like(warped_img[:,:,0])
    for a in range(u.shape[0]):
    #     for b in range(v.shape[0]):
    #     warped_img[xy[a,1],xy[a,0],:] = warped_src_face[v[a],u[a],:]
        if mask[v[a],u[a]]>0:
            warped_img[xy[a,1],xy[a,0],:] = img_target[v[a],u[a],:]
            mask_warped_img[xy[a,1],xy[a,0]] = 255

    return warped_img, mask_warped_img


warped_img, mask_warped_img = warp_tps(img_source,img_target,shape1,shape2,weights_x,weights_y)
plt.imshow(warped_img)

# %%
plt.imshow(mask_warped_img)
mask_warped_img.shape
# Out:
# (200, 200)

# %%
def correct_colours(im1, im2, landmarks1):
    COLOUR_CORRECT_BLUR_FRAC = 0.75
    LEFT_EYE_POINTS = list(range(42, 48))
    RIGHT_EYE_POINTS = list(range(36, 42))

    blur_amount = COLOUR_CORRECT_BLUR_FRAC * np.linalg.norm(
                              np.mean(landmarks1[LEFT_EYE_POINTS], axis=0) -
                              np.mean(landmarks1[RIGHT_EYE_POINTS], axis=0))
    blur_amount = int(blur_amount)
    if blur_amount % 2 == 0:
        blur_amount -= 1
    im1_blur = cv2.GaussianBlur(im1, (blur_amount, blur_amount), 0)
    im2_blur = cv2.GaussianBlur(im2, (blur_amount, blur_amount), 0)
#     im2_blur = im2

    # Avoid divide-by-zero errors.
    im2_blur = im2_blur.astype(int)
    im2_blur += 128*(im2_blur <= 1)

    result = im2.astype(np.float64) * im1_blur.astype(np.float64) / im2_blur.astype(np.float64)
    result = np.clip(result, 0, 255).astype(np.uint8)

    return result

# %%
##Poisson Blending
r = cv2.boundingRect(mask_warped_img)
center = ((r[0] + int(r[2] / 2), r[1] + int(r[3] / 2)))
output = cv2.seamlessClone(warped_img.copy(), img_source, mask_warped_img, center, cv2.NORMAL_CLONE)

# x, y, w, h = dst_shape
# dst_img_cp = img_src.copy()
# dst_img_cp[y:y+h, x:x+w] = output
# output = dst_img_cp

plt.imshow(output)

# %%
plt.imshow(img_source)

# %%
# from scipy.spatial import ConvexHull
# # hull = ConvexHull(shape1)
# points = shape1  
# hull = ConvexHull(points)
# plt.plot(points[:,0], points[:,1], 'o')
# for simplex in hull.simplices:
#     print(simplex)
# #     print(hull)
#     plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
#     plt.plot(points[simplex,0], points[simplex,1], 'ro', alpha=.25, markersize=20)
